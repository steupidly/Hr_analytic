# %%
import psycopg2
import database as db
import pandas as pd
import numpy as np

# %%
# Menyediakan informasi koneksi
# Membuat objek koneksi
connection = psycopg2.connect(
    host= db.host,
    database= db.database,
    user= db.user,
    password=db.password,
    port = db.port
)

#Membuat Cursosr
#membuat ccuror
curr = connection.cursor()

# %%
#Cek Versi PostgreSQL
curr.execute("Select Version();")
record = curr.fetchone()
print("You are connected to - ", record)
# Out:
# You are connected to -  ('PostgreSQL 15.3, compiled by Visual C++ build 1914, 64-bit',)

# %%
curr.execute("""SELECT table_name from information_schema.tables
                WHERE table_schema= 'public'""")

for table in curr.fetchall():
    print(table)
# Out:
# ('hr_set',)

# %%
curr.execute("select sex,avg(salary)  from hr_set hs group by sex ")
record = curr.fetchall()
record
# Out:
# [('M', Decimal('70629.400000000000')), ('F', Decimal('67786.727272727273'))]

# %%
# convert ke pandas
curr.execute("select * from hr_set")
hasil = curr.fetchall()

df = pd.DataFrame(hasil)
df.head(10)
# Out:
#       0       1          2  3         4                          5   \
# 0  10026   62506  7/10/1983  M    Single                      White
# 1  10084  104437   5/5/1975  M   Married                      White
# 2  10196   64955  9/19/1988  F   Married                      White
# 3  10088   64991  9/27/1988  F   Married                      White
# 4  10069   50825   9/8/1989  F  Divorced                      White
# 5  10002   57568  5/22/1977  F    Single                      White
# 6  10194   95660  5/24/1979  F    Single                      White
# 7  10062   59365  2/18/1983  M   Widowed                      White
# 8  10114   47837  2/11/1970  F    Single  Black or African American
# 9  10250   50178   1/7/1988  M  Divorced                      White
#
#                   6                       7                     8   \
# 0  N/A-StillEmployed                  Active            Production
# 1      career change  Voluntarily Terminated                 IT/IS
# ...

# %%
df.to_csv('hr_set_querry.csv')

# %%
curr.close()

# %%
#Membaca CSV menjadi Data Frame
df = pd.read_csv('hr_set_querry.csv')
df.head()
# Out:
#    Unnamed: 0      0       1          2  3         4      5  \
# 0           0  10026   62506  7/10/1983  M    Single  White
# 1           1  10084  104437   5/5/1975  M   Married  White
# 2           2  10196   64955  9/19/1988  F   Married  White
# 3           3  10088   64991  9/27/1988  F   Married  White
# 4           4  10069   50825   9/8/1989  F  Divorced  White
#
#                    6                       7           8              9  \
# 0  N/A-StillEmployed                  Active  Production       LinkedIn
# 1      career change  Voluntarily Terminated       IT/IS         Indeed
# 2              hours  Voluntarily Terminated  Production       LinkedIn
# 3  N/A-StillEmployed                  Active  Production         Indeed
# 4   return to school  Voluntarily Terminated  Production  Google Search
#
#             10  11  12  13
# 0      Exceeds   5   0   1
# 1  Fully Meets   3   6  17
# 2  Fully Meets   3   0   3
# 3  Fully Meets   5   0  15
# 4  Fully Meets   4   0   2

# %%
#Menghapus Column
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#        0       1          2  3         4      5                  6  \
# 0  10026   62506  7/10/1983  M    Single  White  N/A-StillEmployed
# 1  10084  104437   5/5/1975  M   Married  White      career change
# 2  10196   64955  9/19/1988  F   Married  White              hours
# 3  10088   64991  9/27/1988  F   Married  White  N/A-StillEmployed
# 4  10069   50825   9/8/1989  F  Divorced  White   return to school
#
#                         7           8              9           10  11  12  13
# 0                  Active  Production       LinkedIn      Exceeds   5   0   1
# 1  Voluntarily Terminated       IT/IS         Indeed  Fully Meets   3   6  17
# 2  Voluntarily Terminated  Production       LinkedIn  Fully Meets   3   0   3
# 3                  Active  Production         Indeed  Fully Meets   5   0  15
# 4  Voluntarily Terminated  Production  Google Search  Fully Meets   4   0   2

# %%
#Mengganti Nama Column

df_new= df.rename(columns={
                    '0' : 'Emp_ID', 
			        '1' : 'Salary', 
			        '2' : 'DOB',
                    '3' : 'Sex',
			        '4' : 'Marriage',
                    '5' : 'Race', 
			        '6' : 'Status_Emp',
                    '7' : 'Reaso_Term', 
			        '8' : 'Dept',
                    '9' : 'Source_Emp', 
			        '10' : 'Performance',
                    '11' : 'Statification', 
			        '12' :'Project',
                    '13' : 'Absences' })

# %%
df_new.head()
# Out:
#    Emp_ID  Salary        DOB Sex  Marriage   Race         Status_Emp  \
# 0   10026   62506  7/10/1983   M    Single  White  N/A-StillEmployed
# 1   10084  104437   5/5/1975   M   Married  White      career change
# 2   10196   64955  9/19/1988   F   Married  White              hours
# 3   10088   64991  9/27/1988   F   Married  White  N/A-StillEmployed
# 4   10069   50825   9/8/1989   F  Divorced  White   return to school
#
#                Reaso_Term        Dept     Source_Emp  Performance  \
# 0                  Active  Production       LinkedIn      Exceeds
# 1  Voluntarily Terminated       IT/IS         Indeed  Fully Meets
# 2  Voluntarily Terminated  Production       LinkedIn  Fully Meets
# 3                  Active  Production         Indeed  Fully Meets
# 4  Voluntarily Terminated  Production  Google Search  Fully Meets
#
#    Statification  Project  Absences
# 0              5        0         1
# 1              3        6        17
# 2              3        0         3
# ...
